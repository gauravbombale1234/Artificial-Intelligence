# %%
import pandas as pd

# %%
df = pd.read_csv('fake_reg.csv')

# %%
df.head()
# Out:
#         price     feature1     feature2
# 0  461.527929   999.787558   999.766096
# 1  548.130011   998.861615  1001.042403
# 2  410.297162  1000.070267   998.844015
# 3  540.382220   999.952251  1000.440940
# 4  546.024553  1000.446011  1000.338531

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.pairplot(df)
# Out:
# C:\Users\Admin\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
from sklearn.model_selection import train_test_split

# %%
X = df[['feature1','feature2',]].values
y = df['price'].values

X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.3,random_state=0)

# %%
X_train.shape
# Out:
# (700, 2)

# %%
X_test.shape
# Out:
# (300, 2)

# %%
y_train.shape
# Out:
# (700,)

# %%
y_test.shape
# Out:
# (300,)

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
help(MinMaxScaler)
# Out:
# Help on class MinMaxScaler in module sklearn.preprocessing._data:
#
# class MinMaxScaler(sklearn.base.OneToOneFeatureMixin, sklearn.base.TransformerMixin, sklearn.base.BaseEstimator)
#  |  MinMaxScaler(feature_range=(0, 1), *, copy=True, clip=False)
#  |
#  |  Transform features by scaling each feature to a given range.
#  |
#  |  This estimator scales and translates each feature individually such
#  |  that it is in the given range on the training set, e.g. between
#  |  zero and one.
#  |
#  |  The transformation is given by::
#  |
#  |      X_std = (X - X.min(axis=0)) / (X.max(axis=0) - X.min(axis=0))
#  |      X_scaled = X_std * (max - min) + min
#  |
#  |  where min, max = feature_range.
#  |
#  |  This transformation is often used as an alternative to zero mean,
#  |  unit variance scaling.
#  |
#  |  Read more in the :ref:`User Guide <preprocessing_scaler>`.
#  |
#  |  Parameters
#  |  ----------
#  |  feature_range : tuple (min, max), default=(0, 1)
# ...

# %%
scaler = MinMaxScaler()

# %%
scaler.fit(X_train)
# Out:
# MinMaxScaler()

# %%
X_train = scaler.transform(X_train)
X_test = scaler.transform(X_test)

# %% [markdown]
# # Tensorflow 2.0 syntax

# %%
# !pip install tensorflow

# %%
import tensorflow as tf

# %%
from tensorflow.keras.models import Sequential

# %%
help(Sequential)
# Out:
# Help on class Sequential in module keras.src.models.sequential:
#
# class Sequential(keras.src.models.model.Model)
#  |  Sequential(*args, **kwargs)
#  |
#  |  `Sequential` groups a linear stack of layers into a `Model`.
#  |
#  |  Examples:
#  |
#  |  ```python
#  |  model = keras.Sequential()
#  |  model.add(keras.Input(shape=(16,)))
#  |  model.add(keras.layers.Dense(8))
#  |
#  |  # Note that you can also omit the initial `Input`.
#  |  # In that case the model doesn't have any weights until the first call
#  |  # to a training/evaluation method (since it isn't yet built):
#  |  model = keras.Sequential()
#  |  model.add(keras.layers.Dense(8))
#  |  model.add(keras.layers.Dense(4))
#  |  # model.weights not created yet
#  |
#  |  # Whereas if you specify an `Input`, the model gets built
#  |  # continuously as you are adding layers:
#  |  model = keras.Sequential()
#  |  model.add(keras.Input(shape=(16,)))
#  |  model.add(keras.layers.Dense(8))
# ...

# %%
from tensorflow.keras.layers import Dense, Activation

# %%
model = Sequential(
[    Dense(units=3),
    Dense(units=3),
    Dense(units=2)]
)

# %%
model = Sequential()

model.add(Dense(4, activation='relu'))
model.add(Dense(4, activation='relu'))
model.add(Dense(4, activation='relu'))

model.add(Dense(1))

model.compile(optimizer='rmsprop', loss='mse')

# %% [markdown]
# ## Choosing optimizers and loss

# %%
model.fit(X_train, y_train, epochs=250)
# Out:
# Epoch 1/250
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 253883.1719
# Epoch 2/250
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 257404.4062
# Epoch 3/250
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 255726.5312
# Epoch 4/250
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 254934.1719
# Epoch 5/250
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 262026.6719
# Epoch 6/250
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 250446.6562
# Epoch 7/250
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 257404.5781
# Epoch 8/250
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 255282.7656
# Epoch 9/250
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 261786.9688
# Epoch 10/250
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 257917.0156
# Epoch 11/250
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 254615.5938
# Epoch 12/250
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 253552.6250
# Epoch 13/250
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 256177.3281
# Epoch 14/250
# ...

# %%
model.history.history
# Out:
# {'loss': [257299.15625,
#   257126.015625,
#   256945.28125,
#   256761.234375,
#   256574.484375,
#   256383.953125,
#   256194.703125,
#   255999.265625,
#   255789.03125,
#   255557.671875,
#   255302.65625,
#   255021.6875,
#   254715.25,
#   254382.8125,
#   254024.390625,
#   253636.6875,
#   253221.328125,
#   252772.4375,
#   252295.296875,
#   251783.59375,
#   251235.765625,
#   250652.046875,
#   250029.46875,
#   249365.046875,
#   248662.75,
#   247918.28125,
#   247127.40625,
#   246288.484375,
#   245404.953125,
#   244468.59375,
#   243488.640625,
#   242445.984375,
#   241357.1875,
#   240214.1875,
#   239008.28125,
#   237742.03125,
#   236422.40625,
#   235033.6875,
#   233589.984375,
#   232076.0625,
#   230498.125,
#   228847.796875,
#   227132.890625,
#   225337.0,
#   223475.703125,
#   221538.15625,
#   219531.21875,
#   217438.21875,
#   215282.515625,
#   213045.640625,
#   210725.84375,
#   208324.546875,
#   205829.34375,
#   203268.953125,
# ...

# %%
loss_df = pd.DataFrame(model.history.history)

# %%
loss_df.plot()
# Out:
# <Axes: >

# %% [markdown]
# # Compare final evalution (MSE) on training set and test set

# %%
model.evaluate(X_test,y_test,verbose=0)
# Out:
# 28.05670928955078

# %%
# Let us it for training data
model.evaluate(X_train,y_train,verbose=0)
# Out:
# 26.499427795410156

# %% [markdown]
# # Further Evaluation

# %%
test_predictions = model.predict(X_test)
# Out:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step

# %%
test_predictions
# Out:
# array([[513.9359 ],
#        [549.76434],
#        [512.4463 ],
#        [517.97003],
#        [549.4055 ],
#        [548.8337 ],
#        [564.15924],
#        [519.0828 ],
#        [532.2244 ],
#        [603.38586],
#        [503.27197],
#        [619.666  ],
#        [422.5734 ],
#        [353.7943 ],
#        [410.95462],
#        [572.90497],
#        [351.57227],
#        [591.38043],
#        [479.0287 ],
#        [506.41022],
#        [328.34915],
#        [594.77924],
#        [541.94556],
#        [463.55917],
#        [658.9608 ],
#        [655.78687],
#        [641.1156 ],
#        [461.27618],
#        [426.49255],
#        [547.1882 ],
#        [639.7537 ],
#        [570.5816 ],
#        [528.89764],
#        [362.9351 ],
#        [644.38367],
#        [457.70044],
#        [585.23517],
#        [331.08078],
#        [365.54327],
#        [374.3377 ],
#        [588.93567],
#        [457.64548],
#        [434.40704],
#        [421.6268 ],
#        [583.21344],
# ...

# %%
pred_df  = pd.DataFrame(y_test,columns=['Test_Y'])

# %%
pred_df
# Out:
#          Test_Y
# 0    518.356144
# 1    551.650100
# 2    511.366708
# 3    518.127883
# 4    547.624043
# ..          ...
# 295  429.915413
# 296  403.315576
# 297  576.738425
# 298  604.110661
# 299  624.247092
#
# [300 rows x 1 columns]

# %%
test_predictions  = pd.Series(test_predictions.reshape(300,))

# %%
test_predictions
# Out:
# 0      513.935913
# 1      549.764343
# 2      512.446289
# 3      517.970032
# 4      549.405518
#           ...
# 295    430.633484
# 296    405.333984
# 297    577.140198
# 298    612.348145
# 299    625.569702
# Length: 300, dtype: float32

# %%
pred_df = pd.concat([pred_df,test_predictions],axis=1)

# %%
pred_df.columns = ['Test_Y','Model_Predictions']

# %%
pred_df
# Out:
#          Test_Y  Model_Predictions
# 0    518.356144         513.935913
# 1    551.650100         549.764343
# 2    511.366708         512.446289
# 3    518.127883         517.970032
# 4    547.624043         549.405518
# ..          ...                ...
# 295  429.915413         430.633484
# 296  403.315576         405.333984
# 297  576.738425         577.140198
# 298  604.110661         612.348145
# 299  624.247092         625.569702
#
# [300 rows x 2 columns]

# %% [markdown]
# # Lets comapre to the real test labels

# %%
sns.scatterplot(x='Test_Y',y='Model_Predictions',data=pred_df)
# Out:
# <Axes: xlabel='Test_Y', ylabel='Model_Predictions'>

# %%
from sklearn.metrics import mean_absolute_error,mean_squared_error

# %%
mean_absolute_error(pred_df['Test_Y'],pred_df['Model_Predictions'])
# Out:
# 4.181738871311776

# %%
df.describe()
# Out:
#              price     feature1     feature2
# count  1000.000000  1000.000000  1000.000000
# mean    498.673029  1000.014171   999.979847
# std      93.785431     0.974018     0.948330
# min     223.346793   997.058347   996.995651
# 25%     433.025732   999.332068   999.316106
# 50%     502.382117  1000.009915  1000.002243
# 75%     564.921588  1000.637580  1000.645380
# max     774.407854  1003.207934  1002.666308

# %%
# if we will see the mean value of price is 498.67 almost 500 and 1% is 5.The calculated value is 4 which is around 1%. hence it is pretty good

# %%
mean_squared_error(pred_df['Test_Y'], pred_df['Model_Predictions'])
# Out:
# 28.056712782683128

# %% [markdown]
# # Predicting on brand new data

# %%
# [[Feature 1,Feature 2]]
new_gem = [[998,1000]]

# %%
scaler.transform(new_gem)
# Out:
# array([[0.16645635, 0.52647994]])

# %%
new_gem=scaler.transform(new_gem)

# %%
model.predict(new_gem)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# array([[422.4232]], dtype=float32)
